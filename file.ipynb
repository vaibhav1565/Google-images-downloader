# %%
import time
import os
import requests
import sys

# import urllib3
# urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

chrome_options = webdriver.ChromeOptions()
chrome_options.add_experimental_option("detach", True)
chrome_options.add_argument('--disable-blink-features=AutomationControlled')
chrome_options.add_experimental_option(
    "excludeSwitches", ["enable-automation"])
chrome_options.add_experimental_option('useAutomationExtension', False)

# chrome_options.add_argument("--headless")
# chrome_options.add_argument("--disable-gpu")

service = Service(executable_path='./chromedriver')
driver = webdriver.Chrome(service=service, options=chrome_options)
driver.execute_cdp_cmd('Network.setUserAgentOverride', {
                       "userAgent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.53 Safari/537.36'})
driver.execute_script(
    "Object.defineProperty(navigator, 'webdriver', {get: () => undefined})")


query = "Jupiter"
output_folder = query
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

driver.get(f'https://www.google.com/search?q={query}&udm=2')

body = driver.find_element(By.CSS_SELECTOR, "body")
urls = []
WebDriverWait(driver, 25).until(
    EC.visibility_of_element_located(
        (
            By.CSS_SELECTOR, "div[jscontroller='XW992c']")
    )
)
div = driver.find_element(
    By.CSS_SELECTOR, "div[jscontroller='XW992c']")


WebDriverWait(driver, 3).until(
    EC.visibility_of_element_located(
        (By.CSS_SELECTOR, "img[class='YQ4gaf']"))
)
images = div.find_elements(By.CSS_SELECTOR, "img[class='YQ4gaf']")
images[0].click()
selector = "a[class='YsLeY'] > img.sFlh5c.FyHeAf.iPVvYb"
# WebDriverWait(driver, 5).until(
#     EC.presence_of_element_located(
#         (By.CSS_SELECTOR, selector))
# )
# i = driver.find_element(By.CSS_SELECTOR, selector)


urls = []
x = 1
l = len(images)

time.sleep(0.4)
while x < l:
    _ = images[x]

    _.click()
    time.sleep(0.4)
    try :
        i = driver.find_element(By.CSS_SELECTOR, selector)
        print(i.get_attribute('src'))
    except:
        pass

    # try:
        # WebDriverWait(driver, 5).until(
        #     EC.presence_of_element_located(
        #         (By.CSS_SELECTOR, selector))
        # )
        # i = driver.find_element(By.CSS_SELECTOR, selector)
    # except:
    #     print("Exception happened- ")
    #     try:
    #         i = driver.find_element(
    #             By.CSS_SELECTOR, "a[class='YsLeY'] > img.sFlh5c.FyHeAf")
    #     except:
    #         pass

    # src = i.get_attribute('src')
    # urls.append(src)
    # print(f"{x}. {src}")

    x += 1
